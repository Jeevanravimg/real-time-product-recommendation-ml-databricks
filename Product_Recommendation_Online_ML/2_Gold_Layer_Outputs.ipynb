# %%
# %sql
SELECT * 
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_customers_with_age_group
LIMIT 50;

# %%
# %sql
SELECT * 
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_sales_enriched
ORDER BY EventTime DESC
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_user_product_interactions
ORDER BY interaction_score DESC
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_product_features
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_frequently_bought_together
ORDER BY together_orders DESC
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_trending_products_30d
ORDER BY purchase_count DESC
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_user_category_preferences
ORDER BY purchase_count DESC
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_user_price_profile
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_product_price_bands
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_agegroup_popular_products
ORDER BY purchase_count DESC
LIMIT 50;

# %%
# %sql
SELECT *
FROM kusha_solutions.products_recommendation_online_ml_temp.gold_user_product_interactions_weighted
ORDER BY recency_weighted_score DESC
LIMIT 50;

# %%
# %sql
select * from kusha_solutions.products_recommendation_online_ml_temp.gold_final_recommendations
